# %%
using Plots; gadfly!()
y = rand(10)
plot(y, ann=[(3,y[3],"this is #3"), (8,y[8],"this is #8")], size=(600,400))
# Out:
# [Plots.jl] Switched to backend: gadfly
# Plot{Plots.GadflyPackage() n=1}

# %%
plot(y, ann=(3,y[3],"this is #3"), size=(600,400))
annotate!([(5,y[5],"this is #5"),(8.4,y[10],"this is #10")])
# Out:
# Plot{Plots.GadflyPackage() n=1}
