# %%
using Plots
qwt();
# Out:
# [Plots.jl] Switched to backend: qwt

# %%
plot(1:1000,1:1000, xscale=:log10, yscale=:none)
# Out:
# WARNING: Unsupported scale type: none
# Plot{Plots.QwtPackage() n=1}

# %%
plot(1:1000,1:1000, xscale=:id, yscale=:log2)
# Out:
# WARNING: Unsupported scale type: log2
# Plot{Plots.QwtPackage() n=1}
